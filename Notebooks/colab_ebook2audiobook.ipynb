# %% [markdown]
# <a href="https://colab.research.google.com/github/XenoHead2/Digital_Family/blob/main/Notebooks/colab_ebook2audiobook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Welcome to the ebook2audiobook Google Colab!
# ## Features
# - 🔧 **TTS Engines supported**: XTTSv2, Bark, Fairseq, VITS, Tacotron2, Tortoise, GlowTTS, YourTTS- 📚 **Convert multiple file formats**: .epub, .mobi, .azw3, .fb2, .lrf, .rb, .snb, .tcr, .pdf, .txt, .rtf, .doc, .docx, .html, .odt, .azw, .tiff, .tif, .png, .jpg, .jpeg, .bmp
# - 🔍 **OCR scanning** for files with text pages as images
# - 🔊 **High-quality text-to-speech** from near realtime to near real voice
# - 🗣️ **Optional voice cloning** using your own voice file
# - 🌐 **Supports 1158 languages** ([supported languages list](https://dl.fbaipublicfiles.com/mms/tts/all-tts-languages.html))
# - 💻 **Low-resource friendly** — runs on **2 GB RAM / 1 GB VRAM (minimum)**
# - 🎵 **Audiobook output formats**: mono or stereo aac, flac, mp3, m4b, m4a, mp4, mov, ogg, wav, webm
# - 🧠 **SML tags supported** — fine-grained control of breaks, pauses, voice switching and more ([see below](#sml-tags-available))
# - 🧩 **Optional custom model** using your own trained model (XTTSv2 only, other on request)
# - 🎛️ **Fine-tuned preset models** trained by the E2A Team<br/>
#      <i>(Contact us if you need additional fine-tuned models, or if you'd like to share yours to the official preset list)</i>
# ## Want to run locally for free? ⬇
# ## [Check out the ebook2audiobook github!](https://github.com/DrewThomasson/ebook2audiobook)

# %%
# @title 🚀 Run ebook2audiobook!

import os
import subprocess
import time
import shutil
import sysconfig

# Emojis for logs
CHECK_MARK = "✅"
CROSS_MARK = "❌"

SCRIPT_DIR = "/content/ebook2audiobook"

# ── Environment variables (mirrors the bash script) ──────────────────────────
os.environ["PYTHONUTF8"]        = "1"
os.environ["PYTHONIOENCODING"]  = "utf-8"
os.environ["TTS_CACHE"]         = f"{SCRIPT_DIR}/models"
os.environ["TESSDATA_PREFIX"]   = f"{SCRIPT_DIR}/models/tessdata"
os.environ["TMPDIR"]            = f"{SCRIPT_DIR}/tmp"

def display_loading_bar(total_steps):
    print("\n---  LOADING...  Total steps:", total_steps, " ---")

def update_progress(step, total_steps):
    bar_length = 20
    progress_percent = int((step / total_steps) * 100)
    progress_filled = int(bar_length * step / total_steps)
    bar = '=' * progress_filled + '>' + ' ' * max(bar_length - progress_filled - 1, 0)
    print(f"---  PROGRESS:  [{bar}] {progress_percent}% ({step}/{total_steps}) ---")

def run_command_with_log(command, description, step_progress, total_step_commands):
    """Runs a shell command and logs progress, outcome and duration."""
    print(f"\n{step_progress}/{total_step_commands}: {description}...")
    start_time = time.time()
    try:
        process = subprocess.Popen(command, shell=True,
                                   stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        stdout, stderr = process.communicate()
        duration = f"{time.time() - start_time:.2f}"
        if process.returncode != 0:
            print(f"{CROSS_MARK} Command failed: {description} (Took {duration}s)")
            print(f"   Command: {command}")
            print(f"   Error Output:\n{stderr.decode()}")
            return False
        else:
            update_progress(step_progress, total_step_commands)
            print(f"{CHECK_MARK} {step_progress}/{total_step_commands} completed: {description} (Took {duration}s)")
            return True
    except Exception as e:
        duration = f"{time.time() - start_time:.2f}"
        print(f"{CROSS_MARK} Error during: {description} (Took {duration}s) — {e}")
        return False


# ── Step 1 : OS-level packages ────────────────────────────────────────────────
# Mirrors HOST_PROGRAMS from the bash script + Calibre's special installer
os_install_commands = [
    ("apt-get update -qq",
     "Update package lists"),
    ("apt-get install -y -qq libxcb-cursor0 libegl1 libopengl0",
     "Install Calibre display libraries (libxcb-cursor0, libegl1, libopengl0)"),
    ("sudo -v && wget -nv -O- https://download.calibre-ebook.com/linux-installer.sh | sudo sh /dev/stdin",
     "Download & install Calibre"),
    ("apt-get install -y -qq ffmpeg",
     "Install ffmpeg"),
    ("apt-get install -y -qq mediainfo",
     "Install mediainfo"),
    ("apt-get install -y -qq nodejs",
     "Install nodejs"),
    ("apt-get install -y -qq espeak-ng",
     "Install espeak-ng"),
    ("apt-get install -y -qq sox",
     "Install sox"),
    ("apt-get install -y -qq tesseract-ocr tesseract-ocr-eng",
     "Install Tesseract OCR + English language pack"),
    # mecab + unidic (for Japanese support, same as old notebook)
    ("apt-get install -y -qq mecab libmecab-dev mecab-ipadic-utf8",
     "Install mecab (Japanese text analysis)"),
    # Rust is required by some pip packages (e.g. tokenizers)
    ("curl -fsSL https://sh.rustup.rs | sh -s -- -y --quiet && "
     "echo 'source $HOME/.cargo/env' >> ~/.bashrc",
     "Install Rust (required by some Python packages)"),
]

# ── Step 2 : Git clone ────────────────────────────────────────────────────────
git_commands = [
    ("git clone --depth=1 https://github.com/DrewThomasson/ebook2audiobook.git /content/ebook2audiobook",
     "Git clone ebook2audiobook"),
]

# ── Step 3 : Python packages  (mirrors install_python_packages()) ─────────────
# llvmlite/numba must be installed first as pre-built binaries;
# then the rest of requirements.txt is installed line-by-line.
# unidic download closes out the step.
pip_commands = [
    ("pip install -q --upgrade pip setuptools wheel",
     "Upgrade pip / setuptools / wheel"),
    ("pip install -q --upgrade llvmlite numba --only-binary=:all:",
     "Install llvmlite & numba (pre-built binaries only)"),
    ("pip install -q --upgrade --no-cache-dir "
     "-r /content/ebook2audiobook/requirements.txt",
     "Install Python requirements from requirements.txt"),
    ("python -m unidic download",
     "Download Unidic dictionary data"),
]


# ── Helper: sitecustomize hook (mirrors check_sitecustomized()) ───────────────
def install_sitecustomize():
    src = f"{SCRIPT_DIR}/components/sitecustomize.py"
    dst_dir = sysconfig.get_paths()["purelib"]
    dst = os.path.join(dst_dir, "sitecustomize.py")
    if not os.path.exists(src):
        print(f"{CROSS_MARK} sitecustomize.py source not found at {src}, skipping.")
        return False
    if not os.path.exists(dst) or os.path.getmtime(src) > os.path.getmtime(dst):
        shutil.copy2(src, dst)
        print(f"{CHECK_MARK} Installed sitecustomize.py hook → {dst}")
    else:
        print(f"{CHECK_MARK} sitecustomize.py already up-to-date.")
    return True


# ════════════════════════════════════════════════════════════════════════════
# EXECUTION
# ════════════════════════════════════════════════════════════════════════════

# --- Step 1: OS packages ---
print("\n--- Step 1: OS-Level Installations ---")
print("Installs system packages required by the bash script. (~3-5 min)")
display_loading_bar(len(os_install_commands))
step1_ok = True
for i, (cmd, desc) in enumerate(os_install_commands):
    if not run_command_with_log(cmd, desc, i + 1, len(os_install_commands)):
        step1_ok = False
        break

# Activate Rust for the current session after installation
cargo_env = os.path.expanduser("~/.cargo/env")
if os.path.exists(cargo_env):
    os.environ["PATH"] = os.path.expanduser("~/.cargo/bin") + ":" + os.environ.get("PATH", "")

if step1_ok:
    print(f"\n{CHECK_MARK} Step 1: OS-Level Installations — Completed Successfully!")
else:
    print(f"\n{CROSS_MARK} Step 1: OS-Level Installations — Failed. See errors above.")


# --- Step 2: Git Clone ---
print("\n--- Step 2: Git Clone ---")
display_loading_bar(len(git_commands))
step2_ok = True
for i, (cmd, desc) in enumerate(git_commands):
    if not run_command_with_log(cmd, desc, i + 1, len(git_commands)):
        step2_ok = False
        break

if step2_ok:
    print(f"\n{CHECK_MARK} Step 2: Git Clone — Completed Successfully!")
else:
    print(f"\n{CROSS_MARK} Step 2: Git Clone — Failed. See errors above.")


# --- Step 3: Python packages ---
print("\n--- Step 3: Python Package Installation ---")
print("Mirrors install_python_packages() from the bash script. (~3-5 min)")
display_loading_bar(len(pip_commands))
step3_ok = True
for i, (cmd, desc) in enumerate(pip_commands):
    if not run_command_with_log(cmd, desc, i + 1, len(pip_commands)):
        step3_ok = False
        break

if step3_ok:
    print(f"\n{CHECK_MARK} Step 3: Python Package Installation — Completed Successfully!")
else:
    print(f"\n{CROSS_MARK} Step 3: Python Package Installation — Failed. See errors above.")


# --- Step 4: sitecustomize hook ---
print("\n--- Step 4: Installing sitecustomize.py hook ---")
install_sitecustomize()


# --- Step 5: Create required directories ---
print("\n--- Step 5: Creating required directories ---")
for d in ["models", "models/tessdata", "tmp", "run", "audiobooks", "ebooks", "voices"]:
    os.makedirs(f"{SCRIPT_DIR}/{d}", exist_ok=True)
os.chmod(f"{SCRIPT_DIR}/tmp", 0o777)
print(f"{CHECK_MARK} Directories ready.")


# --- Step 6: Run App ---
print("\n--- Step 6: Launch ebook2audiobook ---")
print("Starting the Gradio web interface with a public share link...")
try:
    # script_mode=native matches the NATIVE branch of the bash script;
    # --share creates the public Gradio tunnel link.
    get_ipython().system(
        "cd /content/ebook2audiobook && "
        "python -u app.py --script_mode native --share"
    )
except Exception as e:
    print(f"{CROSS_MARK} Error starting app.py: {e}")

print("\n--- All Steps Completed ---")
print("Check the output above for the public Gradio URL.")
# Out:
# --- Step 1: OS-Level Installations ---
# Installs system packages required by the bash script. (~3-5 min)
#
# ---  LOADING...  Total steps: 11  ---
#
# 1/11: Update package lists...
# ---  PROGRESS:  [=>                  ] 9% (1/11) ---
# ✅ 1/11 completed: Update package lists (Took 6.55s)
#
# 2/11: Install Calibre display libraries (libxcb-cursor0, libegl1, libopengl0)...
# ---  PROGRESS:  [===>                ] 18% (2/11) ---
# ✅ 2/11 completed: Install Calibre display libraries (libxcb-cursor0, libegl1, libopengl0) (Took 8.08s)
#
# 3/11: Download & install Calibre...
# ---  PROGRESS:  [=====>              ] 27% (3/11) ---
# ✅ 3/11 completed: Download & install Calibre (Took 25.99s)
#
# 4/11: Install ffmpeg...
# ---  PROGRESS:  [=======>            ] 36% (4/11) ---
# ✅ 4/11 completed: Install ffmpeg (Took 2.87s)
#
# 5/11: Install mediainfo...
# ---  PROGRESS:  [=========>          ] 45% (5/11) ---
# ✅ 5/11 completed: Install mediainfo (Took 7.02s)
#
# 6/11: Install nodejs...
# ---  PROGRESS:  [==========>         ] 54% (6/11) ---
# ✅ 6/11 completed: Install nodejs (Took 8.31s)
#
# 7/11: Install espeak-ng...
# ---  PROGRESS:  [============>       ] 63% (7/11) ---
# ✅ 7/11 completed: Install espeak-ng (Took 6.26s)
#
# 8/11: Install sox...
# ---  PROGRESS:  [==============>     ] 72% (8/11) ---
# ✅ 8/11 completed: Install sox (Took 7.06s)
#
# 9/11: Install Tesseract OCR + English language pack...
# ---  PROGRESS:  [================>   ] 81% (9/11) ---
# ✅ 9/11 completed: Install Tesseract OCR + English language pack (Took 2.60s)
#
# 10/11: Install mecab (Japanese text analysis)...
# ---  PROGRESS:  [==================> ] 90% (10/11) ---
# ✅ 10/11 completed: Install mecab (Japanese text analysis) (Took 12.67s)
#
# 11/11: Install Rust (required by some Python packages)...
# ❌ Command failed: Install Rust (required by some Python packages) (Took 0.30s)
#    Command: curl -fsSL https://sh.rustup.rs | sh -s -- -y --quiet && echo 'source $HOME/.cargo/env' >> ~/.bashrc
#    Error Output:
# mktemp: failed to create directory via template ‘/content/ebook2audiobook/tmp/tmp.XXXXXXXXXX’: No such file or directory
# error: command failed: mktemp -d
#
#
# ❌ Step 1: OS-Level Installations — Failed. See errors above.
#
# --- Step 2: Git Clone ---
#
# ---  LOADING...  Total steps: 1  ---
#
# 1/1: Git clone ebook2audiobook...
# ---  PROGRESS:  [====================>] 100% (1/1) ---
# ✅ 1/1 completed: Git clone ebook2audiobook (Took 8.50s)
#
# ✅ Step 2: Git Clone — Completed Successfully!
#
# --- Step 3: Python Package Installation ---
# Mirrors install_python_packages() from the bash script. (~3-5 min)
#
# ---  LOADING...  Total steps: 4  ---
#
# 1/4: Upgrade pip / setuptools / wheel...
# ---  PROGRESS:  [=====>              ] 25% (1/4) ---
# ✅ 1/4 completed: Upgrade pip / setuptools / wheel (Took 11.47s)
#
# 2/4: Install llvmlite & numba (pre-built binaries only)...
# ---  PROGRESS:  [==========>         ] 50% (2/4) ---
# ✅ 2/4 completed: Install llvmlite & numba (pre-built binaries only) (Took 8.96s)
#
# 3/4: Install Python requirements from requirements.txt...
# ❌ Command failed: Install Python requirements from requirements.txt (Took 0.49s)
#    Command: pip install -q --upgrade --no-cache-dir -r /content/ebook2audiobook/requirements.txt
#    Error Output:
# ERROR: Invalid requirement: 'ext/py/num2words': Expected semicolon (after name with no version specifier) or end
#     ext/py/num2words
#        ^ (from line 43 of /content/ebook2audiobook/requirements.txt)
# Hint: It looks like a path. File 'ext/py/num2words' does not exist.
#
#
# ❌ Step 3: Python Package Installation — Failed. See errors above.
#
# --- Step 4: Installing sitecustomize.py hook ---
# ✅ Installed sitecustomize.py hook → /usr/local/lib/python3.12/dist-packages/sitecustomize.py
#
# --- Step 5: Creating required directories ---
# ✅ Directories ready.
#
# --- Step 6: Launch ebook2audiobook ---
# Starting the Gradio web interface with a public share link...
# v26.4.22 native mode
# torchvggish is not installed.
# docker is not installed.
# ebooklib is not installed.
# python-pptx is not installed.
# python-docx is not installed.
# nagisa is not installed.
# pymupdf is not installed.
# pymupdf-layout is not installed.
# pytesseract is not installed.
# unidic is not installed.
# hangul-romanize is not installed.
# iso639-lang is not installed.
# soynlp is not installed.
# pycantonese is not installed.
# pypinyin is not installed.
# pythainlp is not installed.
# mutagen is not installed.
# phonemizer-fork is not installed.
# unidecode is not installed.
# langdetect is not installed.
# phonemizer is not installed.
# indic-nlp-library is not installed.
# stanza is not installed.
# pyannote-audio is not installed.
# argostranslate is not installed.
# gradio (installed 5.50.0) != required 5.49.1.
# transformers (installed 5.0.0) != required 4.57.6.
# coqui-tts is not installed.
# num2words is not installed.
# demucs is not installed.
#
# Installing missing or upgrade packages…
#
# WARNING: No matching packages
# Files removed: 0 (0 bytes)
# Directories removed: 0
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (26.0.1)
# Collecting torchvggish
#   Downloading torchvggish-0.2.tar.gz (9.7 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvggish) (2.0.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from torchvggish) (2.10.0+cu128)
# Collecting resampy (from torchvggish)
#   Downloading resampy-0.4.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numba>=0.53 in /usr/local/lib/python3.12/dist-packages (from resampy->torchvggish) (0.65.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.53->resampy->torchvggish) (0.47.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (82.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->torchvggish) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->torchvggish) (1.5.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->torchvggish) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->torchvggish) (3.0.3)
# Downloading resampy-0.4.3-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 19.2 MB/s  0:00:00
# Building wheels for collected packages: torchvggish
#   Building wheel for torchvggish (pyproject.toml) ... done
#   Created wheel for torchvggish: filename=torchvggish-0.2-py3-none-any.whl size=10591 sha256=cb496a24611203fcc45a8fd942b2642388baf185034affc5836b04be9abc2bf6
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-eg5mw7e1/wheels/77/ae/2d/b419f4e64405724c53564c569cb1234e5d1f1e6a47a47b4fcd
# Successfully built torchvggish
# Installing collected packages: resampy, torchvggish
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [torchvggish]
# Successfully installed resampy-0.4.3 torchvggish-0.2
# Collecting docker
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from docker) (2.32.4)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from docker) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->docker) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->docker) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->docker) (2026.2.25)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Installing collected packages: docker
# Successfully installed docker-7.1.0
# Collecting ebooklib
#   Downloading ebooklib-0.20-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from ebooklib) (6.0.3)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from ebooklib) (1.17.0)
# Downloading ebooklib-0.20-py3-none-any.whl (40 kB)
# Installing collected packages: ebooklib
# Successfully installed ebooklib-0.20
# Collecting python-pptx
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.12/dist-packages (from python-pptx) (11.3.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx)
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-pptx) (6.0.3)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from python-pptx) (4.15.0)
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
# Installing collected packages: XlsxWriter, python-pptx
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [python-pptx]
# Successfully installed XlsxWriter-3.2.9 python-pptx-1.0.2
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (6.0.3)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (4.15.0)
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
# Installing collected packages: python-docx
# Successfully installed python-docx-1.2.0
# Collecting nagisa
#   Downloading nagisa-0.2.12-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.2 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from nagisa) (1.17.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from nagisa) (2.0.2)
# Collecting DyNet38 (from nagisa)
#   Downloading dyNET38-2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: cython in /usr/local/lib/python3.12/dist-packages (from DyNet38->nagisa) (3.0.12)
# Downloading nagisa-0.2.12-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (21.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.7/21.7 MB 64.6 MB/s  0:00:00
# Downloading dyNET38-2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 143.4 MB/s  0:00:00
# Installing collected packages: DyNet38, nagisa
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [nagisa]
# Successfully installed DyNet38-2.2 nagisa-0.2.12
# Collecting pymupdf
#   Downloading pymupdf-1.27.2.2-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.27.2.2-cp310-abi3-manylinux_2_28_x86_64.whl (24.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 66.2 MB/s  0:00:00
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.27.2.2
# Collecting pymupdf-layout
#   Downloading pymupdf_layout-1.27.2.2-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: PyMuPDF==1.27.2.2 in /usr/local/lib/python3.12/dist-packages (from pymupdf-layout) (1.27.2.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from pymupdf-layout) (6.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pymupdf-layout) (2.0.2)
# Collecting onnxruntime (from pymupdf-layout)
#   Downloading onnxruntime-1.25.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from pymupdf-layout) (3.6.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime->pymupdf-layout) (25.12.19)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime->pymupdf-layout) (26.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime->pymupdf-layout) (5.29.6)
# Downloading pymupdf_layout-1.27.2.2-cp310-abi3-manylinux_2_28_x86_64.whl (15.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 51.5 MB/s  0:00:00
# Downloading onnxruntime-1.25.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 168.5 MB/s  0:00:00
# Installing collected packages: onnxruntime, pymupdf-layout
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pymupdf-layout]
# Successfully installed onnxruntime-1.25.0 pymupdf-layout-1.27.2.2
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from pytesseract) (26.0)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from pytesseract) (11.3.0)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13
# Collecting unidic
#   Downloading unidic-1.1.0.tar.gz (7.7 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests<3.0.0,>=2.22.0 in /usr/local/lib/python3.12/dist-packages (from unidic) (2.32.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.41.1 in /usr/local/lib/python3.12/dist-packages (from unidic) (4.67.3)
# Collecting wasabi<1.0.0,>=0.6.0 (from unidic)
#   Downloading wasabi-0.10.1-py3-none-any.whl.metadata (28 kB)
# Collecting plac<2.0.0,>=1.1.3 (from unidic)
#   Downloading plac-1.4.5-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.22.0->unidic) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.22.0->unidic) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.22.0->unidic) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.22.0->unidic) (2026.2.25)
# Downloading plac-1.4.5-py2.py3-none-any.whl (22 kB)
# Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Building wheels for collected packages: unidic
#   Building wheel for unidic (pyproject.toml) ... done
#   Created wheel for unidic: filename=unidic-1.1.0-py3-none-any.whl size=7471 sha256=d9ee8399d6ab3f23a1cb3b013b97706dd841d3bf3634e8f732a350014ead14fe
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-s_u774sw/wheels/cb/04/a2/659428f84ed1fa7257f8efb544b36043dd37a7c419e8ca711a
# Successfully built unidic
# Installing collected packages: wasabi, plac, unidic
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.3
#     Uninstalling wasabi-1.1.3:
#       Successfully uninstalled wasabi-1.1.3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [unidic]
# Successfully installed plac-1.4.5 unidic-1.1.0 wasabi-0.10.1
# Collecting hangul-romanize
#   Downloading hangul_romanize-0.1.0-py3-none-any.whl.metadata (1.2 kB)
# Downloading hangul_romanize-0.1.0-py3-none-any.whl (4.6 kB)
# Installing collected packages: hangul-romanize
# Successfully installed hangul-romanize-0.1.0
# Collecting iso639-lang
#   Downloading iso639_lang-2.6.3-py3-none-any.whl.metadata (8.4 kB)
# Downloading iso639_lang-2.6.3-py3-none-any.whl (324 kB)
# Installing collected packages: iso639-lang
# Successfully installed iso639-lang-2.6.3
# Collecting soynlp
#   Downloading soynlp-0.0.493-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: numpy>=1.12.1 in /usr/local/lib/python3.12/dist-packages (from soynlp) (2.0.2)
# Requirement already satisfied: psutil>=5.0.1 in /usr/local/lib/python3.12/dist-packages (from soynlp) (5.9.5)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from soynlp) (1.16.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from soynlp) (1.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.20.0->soynlp) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.20.0->soynlp) (3.6.0)
# Downloading soynlp-0.0.493-py3-none-any.whl (416 kB)
# Installing collected packages: soynlp
# Successfully installed soynlp-0.0.493
# Collecting pycantonese
#   Downloading pycantonese-4.2.0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.9 kB)
# Collecting rustling>=0.8.0 (from pycantonese)
#   Downloading rustling-0.8.0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Downloading pycantonese-4.2.0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 MB 50.5 MB/s  0:00:00
# Downloading rustling-0.8.0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 143.5 MB/s  0:00:00
# Installing collected packages: rustling, pycantonese
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pycantonese]
# Successfully installed pycantonese-4.2.0 rustling-0.8.0
# Collecting pypinyin
#   Downloading pypinyin-0.55.0-py2.py3-none-any.whl.metadata (12 kB)
# Downloading pypinyin-0.55.0-py2.py3-none-any.whl (840 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.2/840.2 kB 20.7 MB/s  0:00:00
# Installing collected packages: pypinyin
# Successfully installed pypinyin-0.55.0
# Collecting pythainlp
#   Downloading pythainlp-5.3.4-py3-none-any.whl.metadata (23 kB)
# Downloading pythainlp-5.3.4-py3-none-any.whl (19.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 61.5 MB/s  0:00:00
# Installing collected packages: pythainlp
# Successfully installed pythainlp-5.3.4
# Collecting mutagen
#   Downloading mutagen-1.47.0-py3-none-any.whl.metadata (1.7 kB)
# Downloading mutagen-1.47.0-py3-none-any.whl (194 kB)
# Installing collected packages: mutagen
# Successfully installed mutagen-1.47.0
# Collecting phonemizer-fork
#   Downloading phonemizer_fork-3.3.2-py3-none-any.whl.metadata (48 kB)
# Requirement already satisfied: attrs>=18.1 in /usr/local/lib/python3.12/dist-packages (from phonemizer-fork) (26.1.0)
# Collecting dlinfo (from phonemizer-fork)
#   Downloading dlinfo-2.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from phonemizer-fork) (1.5.3)
# Collecting segments (from phonemizer-fork)
#   Downloading segments-2.4.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from phonemizer-fork) (4.15.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from segments->phonemizer-fork) (2025.11.3)
# Collecting csvw>=1.5.6 (from segments->phonemizer-fork)
#   Downloading csvw-3.7.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting isodate (from csvw>=1.5.6->segments->phonemizer-fork)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from csvw>=1.5.6->segments->phonemizer-fork) (2.9.0.post0)
# Collecting rfc3986<2 (from csvw>=1.5.6->segments->phonemizer-fork)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: uritemplate>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from csvw>=1.5.6->segments->phonemizer-fork) (4.2.0)
# Requirement already satisfied: babel in /usr/local/lib/python3.12/dist-packages (from csvw>=1.5.6->segments->phonemizer-fork) (2.18.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from csvw>=1.5.6->segments->phonemizer-fork) (2.32.4)
# Collecting language-tags (from csvw>=1.5.6->segments->phonemizer-fork)
#   Downloading language_tags-1.2.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting rdflib (from csvw>=1.5.6->segments->phonemizer-fork)
#   Downloading rdflib-7.6.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from csvw>=1.5.6->segments->phonemizer-fork) (3.3.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from csvw>=1.5.6->segments->phonemizer-fork) (4.26.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer-fork) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer-fork) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer-fork) (0.30.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->csvw>=1.5.6->segments->phonemizer-fork) (1.17.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from rdflib->csvw>=1.5.6->segments->phonemizer-fork) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->csvw>=1.5.6->segments->phonemizer-fork) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->csvw>=1.5.6->segments->phonemizer-fork) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->csvw>=1.5.6->segments->phonemizer-fork) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->csvw>=1.5.6->segments->phonemizer-fork) (2026.2.25)
# Downloading phonemizer_fork-3.3.2-py3-none-any.whl (82 kB)
# Downloading dlinfo-2.0.0-py3-none-any.whl (3.7 kB)
# Downloading segments-2.4.0-py2.py3-none-any.whl (16 kB)
# Downloading csvw-3.7.0-py2.py3-none-any.whl (60 kB)
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading language_tags-1.2.0-py3-none-any.whl (213 kB)
# Downloading rdflib-7.6.0-py3-none-any.whl (615 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.4/615.4 kB 15.1 MB/s  0:00:00
# Installing collected packages: rfc3986, language-tags, rdflib, isodate, dlinfo, csvw, segments, phonemizer-fork
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [phonemizer-fork]
# Successfully installed csvw-3.7.0 dlinfo-2.0.0 isodate-0.7.2 language-tags-1.2.0 phonemizer-fork-3.3.2 rdflib-7.6.0 rfc3986-1.5.0 segments-2.4.0
# Collecting unidecode
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
# Installing collected packages: unidecode
# Successfully installed unidecode-1.4.0
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 16.0 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from langdetect) (1.17.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (pyproject.toml) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993332 sha256=fdf9d5bfcd35c624541bcb1540f41c0ad5cb53128c0b22f7fd18577c97b5797a
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-qeuunyd1/wheels/c1/67/88/e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9
# Collecting phonemizer
#   Downloading phonemizer-3.3.0-py3-none-any.whl.metadata (48 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from phonemizer) (1.5.3)
# Requirement already satisfied: segments in /usr/local/lib/python3.12/dist-packages (from phonemizer) (2.4.0)
# Requirement already satisfied: attrs>=18.1 in /usr/local/lib/python3.12/dist-packages (from phonemizer) (26.1.0)
# Requirement already satisfied: dlinfo in /usr/local/lib/python3.12/dist-packages (from phonemizer) (2.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from phonemizer) (4.15.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from segments->phonemizer) (2025.11.3)
# Requirement already satisfied: csvw>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from segments->phonemizer) (3.7.0)
# Requirement already satisfied: isodate in /usr/local/lib/python3.12/dist-packages (from csvw>=1.5.6->segments->phonemizer) (0.7.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from csvw>=1.5.6->segments->phonemizer) (2.9.0.post0)
# Requirement already satisfied: rfc3986<2 in /usr/local/lib/python3.12/dist-packages (from csvw>=1.5.6->segments->phonemizer) (1.5.0)
# Requirement already satisfied: uritemplate>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from csvw>=1.5.6->segments->phonemizer) (4.2.0)
# Requirement already satisfied: babel in /usr/local/lib/python3.12/dist-packages (from csvw>=1.5.6->segments->phonemizer) (2.18.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from csvw>=1.5.6->segments->phonemizer) (2.32.4)
# Requirement already satisfied: language-tags in /usr/local/lib/python3.12/dist-packages (from csvw>=1.5.6->segments->phonemizer) (1.2.0)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.12/dist-packages (from csvw>=1.5.6->segments->phonemizer) (7.6.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from csvw>=1.5.6->segments->phonemizer) (3.3.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from csvw>=1.5.6->segments->phonemizer) (4.26.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer) (0.30.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->csvw>=1.5.6->segments->phonemizer) (1.17.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from rdflib->csvw>=1.5.6->segments->phonemizer) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->csvw>=1.5.6->segments->phonemizer) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->csvw>=1.5.6->segments->phonemizer) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->csvw>=1.5.6->segments->phonemizer) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->csvw>=1.5.6->segments->phonemizer) (2026.2.25)
# Downloading phonemizer-3.3.0-py3-none-any.whl (103 kB)
# Installing collected packages: phonemizer
# Successfully installed phonemizer-3.3.0
# Collecting indic-nlp-library
#   Downloading indic_nlp_library-0.92-py3-none-any.whl.metadata (5.7 kB)
# Collecting sphinx-argparse (from indic-nlp-library)
#   Downloading sphinx_argparse-0.5.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting sphinx-rtd-theme (from indic-nlp-library)
#   Downloading sphinx_rtd_theme-3.1.0-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting morfessor (from indic-nlp-library)
#   Downloading Morfessor-2.0.6-py3-none-any.whl.metadata (628 bytes)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from indic-nlp-library) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from indic-nlp-library) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->indic-nlp-library) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->indic-nlp-library) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library) (1.17.0)
# Requirement already satisfied: sphinx>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from sphinx-argparse->indic-nlp-library) (8.2.3)
# Requirement already satisfied: docutils>=0.19 in /usr/local/lib/python3.12/dist-packages (from sphinx-argparse->indic-nlp-library) (0.21.2)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.6)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.20.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.18.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.32.4)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (4.1.0)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (26.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from Jinja2>=3.1->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2026.2.25)
# Requirement already satisfied: roman-numerals==4.1.0 in /usr/local/lib/python3.12/dist-packages (from roman-numerals-py>=1.0.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (4.1.0)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme->indic-nlp-library)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Downloading indic_nlp_library-0.92-py3-none-any.whl (40 kB)
# Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Downloading sphinx_argparse-0.5.2-py3-none-any.whl (12 kB)
# Downloading sphinx_rtd_theme-3.1.0-py2.py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 31.1 MB/s  0:00:00
# Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
# Installing collected packages: morfessor, sphinxcontrib-jquery, sphinx-argparse, sphinx-rtd-theme, indic-nlp-library
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [indic-nlp-library]
# Successfully installed indic-nlp-library-0.92 morfessor-2.0.6 sphinx-argparse-0.5.2 sphinx-rtd-theme-3.1.0 sphinxcontrib-jquery-4.1
# Collecting stanza==1.10.1
#   Downloading stanza-1.10.1-py3-none-any.whl.metadata (13 kB)
# Collecting emoji (from stanza==1.10.1)
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from stanza==1.10.1) (2.0.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.12/dist-packages (from stanza==1.10.1) (5.29.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from stanza==1.10.1) (2.32.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from stanza==1.10.1) (3.6.1)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from stanza==1.10.1) (2.10.0+cu128)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from stanza==1.10.1) (4.67.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (82.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.3.0->stanza==1.10.1) (1.5.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.3.0->stanza==1.10.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.3.0->stanza==1.10.1) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->stanza==1.10.1) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->stanza==1.10.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->stanza==1.10.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->stanza==1.10.1) (2026.2.25)
# Downloading stanza-1.10.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.8 MB/s  0:00:00
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 20.9 MB/s  0:00:00
# Installing collected packages: emoji, stanza
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [stanza]
# Successfully installed emoji-2.15.0 stanza-1.10.1
# Collecting pyannote-audio==3.4.0
#   Downloading pyannote_audio-3.4.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting asteroid-filterbanks>=0.4 (from pyannote-audio==3.4.0)
#   Downloading asteroid_filterbanks-0.4.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio==3.4.0) (0.8.2)
# Requirement already satisfied: huggingface_hub>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio==3.4.0) (1.10.1)
# Collecting lightning>=2.0.1 (from pyannote-audio==3.4.0)
#   Downloading lightning-2.6.1-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: omegaconf<3.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio==3.4.0) (2.3.0)
# Collecting pyannote.core<6.0,>=5.0.0 (from pyannote-audio==3.4.0)
#   Downloading pyannote.core-5.0.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting pyannote.database<6.0,>=5.0.1 (from pyannote-audio==3.4.0)
#   Downloading pyannote.database-5.1.3-py3-none-any.whl.metadata (1.1 kB)
# Collecting pyannote.metrics<4.0,>=3.2 (from pyannote-audio==3.4.0)
#   Downloading pyannote.metrics-3.2.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting pyannote.pipeline<4.0,>=3.0.1 (from pyannote-audio==3.4.0)
#   Downloading pyannote.pipeline-3.0.1-py3-none-any.whl.metadata (897 bytes)
# Collecting pytorch_metric_learning>=2.1.0 (from pyannote-audio==3.4.0)
#   Downloading pytorch_metric_learning-2.9.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio==3.4.0) (13.9.4)
# Collecting semver>=3.0.0 (from pyannote-audio==3.4.0)
#   Downloading semver-3.0.4-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio==3.4.0) (0.13.1)
# Collecting speechbrain>=1.0.0 (from pyannote-audio==3.4.0)
#   Downloading speechbrain-1.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting tensorboardX>=2.6 (from pyannote-audio==3.4.0)
#   Downloading tensorboardx-2.6.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio==3.4.0) (2.10.0+cu128)
# Collecting torch_audiomentations>=0.11.0 (from pyannote-audio==3.4.0)
#   Downloading torch_audiomentations-0.12.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torchaudio>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio==3.4.0) (2.10.0+cu128)
# Collecting torchmetrics>=0.11.0 (from pyannote-audio==3.4.0)
#   Downloading torchmetrics-1.9.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf<3.0,>=2.1->pyannote-audio==3.4.0) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from omegaconf<3.0,>=2.1->pyannote-audio==3.4.0) (6.0.3)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from pyannote.core<6.0,>=5.0.0->pyannote-audio==3.4.0) (2.4.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.12/dist-packages (from pyannote.core<6.0,>=5.0.0->pyannote-audio==3.4.0) (2.0.2)
# Requirement already satisfied: scipy>=1.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.core<6.0,>=5.0.0->pyannote-audio==3.4.0) (1.16.3)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.core<6.0,>=5.0.0->pyannote-audio==3.4.0) (4.15.0)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.12/dist-packages (from pyannote.database<6.0,>=5.0.1->pyannote-audio==3.4.0) (2.2.2)
# Requirement already satisfied: typer>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.database<6.0,>=5.0.1->pyannote-audio==3.4.0) (0.24.1)
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.metrics<4.0,>=3.2->pyannote-audio==3.4.0) (1.6.1)
# Collecting docopt>=0.6.2 (from pyannote.metrics<4.0,>=3.2->pyannote-audio==3.4.0)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.12/dist-packages (from pyannote.metrics<4.0,>=3.2->pyannote-audio==3.4.0) (0.9.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote.metrics<4.0,>=3.2->pyannote-audio==3.4.0) (3.10.0)
# Requirement already satisfied: sympy>=1.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.metrics<4.0,>=3.2->pyannote-audio==3.4.0) (1.14.0)
# Collecting optuna>=3.1 (from pyannote.pipeline<4.0,>=3.0.1->pyannote-audio==3.4.0)
#   Downloading optuna-4.8.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: tqdm>=4.29.1 in /usr/local/lib/python3.12/dist-packages (from pyannote.pipeline<4.0,>=3.0.1->pyannote-audio==3.4.0) (4.67.3)
# Requirement already satisfied: filelock>=3.0.10 in /usr/local/lib/python3.12/dist-packages (from pyannote.pipeline<4.0,>=3.0.1->pyannote-audio==3.4.0) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.13.0->pyannote-audio==3.4.0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.13.0->pyannote-audio==3.4.0) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.13.0->pyannote-audio==3.4.0) (0.28.1)
# ...
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate==1.10.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate==1.10.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate==1.10.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate==1.10.0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate==1.10.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate==1.10.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate==1.10.0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3.0->stanza==1.10.1->argostranslate==1.10.0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.3.0->stanza==1.10.1->argostranslate==1.10.0) (1.5.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.3.0->stanza==1.10.1->argostranslate==1.10.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.3.0->stanza==1.10.1->argostranslate==1.10.0) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->stanza==1.10.1->argostranslate==1.10.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->stanza==1.10.1->argostranslate==1.10.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->stanza==1.10.1->argostranslate==1.10.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->stanza==1.10.1->argostranslate==1.10.0) (2026.2.25)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate==1.10.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate==1.10.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate==1.10.0) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate==1.10.0) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate==1.10.0) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate==1.10.0) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate==1.10.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate==1.10.0) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate==1.10.0) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate==1.10.0) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate==1.10.0) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate==1.10.0) (0.24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy->argostranslate==1.10.0) (2.12.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy->argostranslate==1.10.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy->argostranslate==1.10.0) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy->argostranslate==1.10.0) (0.4.2)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.12->spacy->argostranslate==1.10.0) (1.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy->argostranslate==1.10.0) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy->argostranslate==1.10.0) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy->argostranslate==1.10.0) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy->argostranslate==1.10.0) (0.23.0)
# Requirement already satisfied: smart-open>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy->argostranslate==1.10.0) (7.5.1)
# Requirement already satisfied: httpx>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy->argostranslate==1.10.0) (0.28.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy->argostranslate==1.10.0) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy->argostranslate==1.10.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy->argostranslate==1.10.0) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy->argostranslate==1.10.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy->argostranslate==1.10.0) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy->argostranslate==1.10.0) (0.1.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy->argostranslate==1.10.0) (2.1.2)
# Downloading argostranslate-1.10.0-py3-none-any.whl (41 kB)
# Downloading ctranslate2-4.7.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (39.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.0/39.0 MB 93.1 MB/s  0:00:00
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 447.6 MB/s  0:00:00
# Installing collected packages: sacremoses, ctranslate2, argostranslate
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [argostranslate]
# Successfully installed argostranslate-1.10.0 ctranslate2-4.7.1 sacremoses-0.1.1
# Collecting gradio==5.49.1
#   Downloading gradio-5.49.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (4.13.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (0.135.3)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (1.0.0)
# Collecting gradio-client==1.13.3 (from gradio==5.49.1)
#   Downloading gradio_client-1.13.3-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (1.10.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (2.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (3.11.8)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (26.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (11.3.0)
# Collecting pydantic<2.12,>=2.0 (from gradio==5.49.1)
#   Downloading pydantic-2.11.10-py3-none-any.whl.metadata (68 kB)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (0.0.26)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (6.0.3)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (0.15.10)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (0.52.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (0.24.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1) (0.44.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.13.3->gradio==5.49.1) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.13.3->gradio==5.49.1) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio==5.49.1) (3.11)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio==5.49.1) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio==5.49.1) (0.0.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio==5.49.1) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio==5.49.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio==5.49.1) (0.16.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio==5.49.1) (3.25.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio==5.49.1) (1.4.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio==5.49.1) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==5.49.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==5.49.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==5.49.1) (2026.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio==5.49.1) (0.7.0)
# Collecting pydantic-core==2.33.2 (from pydantic<2.12,>=2.0->gradio==5.49.1)
#   Downloading pydantic_core-2.33.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==5.49.1) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==5.49.1) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==5.49.1) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio==5.49.1) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio==5.49.1) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio==5.49.1) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio==5.49.1) (0.1.2)
# Downloading gradio-5.49.1-py3-none-any.whl (63.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 MB 117.6 MB/s  0:00:00
# Downloading gradio_client-1.13.3-py3-none-any.whl (325 kB)
# Downloading pydantic-2.11.10-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 341.6 MB/s  0:00:00
# Installing collected packages: pydantic-core, pydantic, gradio-client, gradio
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.41.4
#     Uninstalling pydantic_core-2.41.4:
#       Successfully uninstalled pydantic_core-2.41.4
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.12.3
#     Uninstalling pydantic-2.12.3:
#       Successfully uninstalled pydantic-2.12.3
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio_client 1.14.0
#     Uninstalling gradio_client-1.14.0:
#       Successfully uninstalled gradio_client-1.14.0
#   Attempting uninstall: gradio
#     Found existing installation: gradio 5.50.0
#     Uninstalling gradio-5.50.0:
#       Successfully uninstalled gradio-5.50.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [gradio]
